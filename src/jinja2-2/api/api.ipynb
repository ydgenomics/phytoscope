# %%
import jinja2
import plotly

# %%
# import subprocess
# import sys
# package = 'jinja2'
# install_command = [sys.executable, "-m", "pip", "install", package]
# subprocess.check_call(install_command)
